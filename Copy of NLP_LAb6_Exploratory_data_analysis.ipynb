# %% [markdown]
# #Lab Exercise: 6
# Perform Exploratory Data Analysis using following:
# * Word Cloud
# * Frequent Word Detection
# * Keyword Extraction based on ranking
# * Dictionary Building
# * N-gram tokenization

# %% [markdown]
# **Exploratory Data Analysis** refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.

# %%
#word cloud
# !pip install wordcloud matplotlib pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (3.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# #Project Gutenberg is a library of over 60,000 free eBooks
#
# #About projectgutenberg
#
# This package contains a variety of scripts to make working with the Project Gutenberg body of public domain texts easier.
#
# The functionality provided by this package includes:
#
# Downloading texts from Project Gutenberg.
#
# Cleaning the texts: removing all the crud, leaving just the text behind.
#
# Making meta-data about the texts easily accessible.
#
# NLTK includes a small selection of texts from the Project Gutenberg electronic text archive

# %%
nltk.download('gutenberg')  #Project Gutenberg is a library of over 60,000 free eBooks
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# #1)Wordcloud

# %%
# load the dataset
dataset = nltk.corpus.gutenberg.words('austen-emma.txt') #pick out the first text from projectGutenberg — Emma by Jane Austen 


len(dataset)
type(dataset)
# Out:
# nltk.corpus.reader.util.StreamBackedCorpusView

# %%
print(dataset[:100])
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', ',', 'handsome', ',', 'clever', ',', 'and', 'rich', ',', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', ',', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', ';', 'and', 'had', 'lived', 'nearly', 'twenty', '-', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', '.', 'She', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate', ',', 'indulgent', 'father', ';', 'and', 'had', ',', 'in', 'consequence', 'of', 'her', 'sister', "'", 's', 'marriage', ',', 'been', 'mistress', 'of', 'his', 'house', 'from', 'a', 'very', 'early', 'period', '.', 'Her']

# %%
# convert the dataset to a string
text = " ".join(dataset)

# tokenize the text data
tokens = word_tokenize(text)

# remove stop words and punctuation marks
stop_words = set(stopwords.words("english"))
tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

# count the frequency of each word
word_counts = Counter(tokens)

# %%
word_counts
# Out:
# Counter({'emma': 865,
#          'jane': 301,
#          'austen': 1,
#          'volume': 3,
#          'chapter': 56,
#          'woodhouse': 313,
#          'handsome': 38,
#          'clever': 27,
#          'rich': 14,
#          'comfortable': 34,
#          'home': 130,
#          'happy': 125,
#          'disposition': 24,
#          'seemed': 141,
#          'unite': 3,
#          'best': 85,
#          'blessings': 6,
#          'existence': 8,
#          'lived': 25,
#          'nearly': 14,
#          'twenty': 30,
#          'one': 452,
#          'years': 57,
#          'world': 81,
#          'little': 359,
#          'distress': 19,
#          'vex': 1,
#          'youngest': 4,
#          'two': 178,
#          'daughters': 7,
#          'affectionate': 9,
#          'indulgent': 2,
#          'father': 207,
#          'consequence': 27,
#          'sister': 33,
#          'marriage': 35,
#          'mistress': 11,
#          'house': 95,
#          'early': 41,
#          'period': 18,
#          'mother': 72,
#          'died': 4,
#          'long': 146,
#          'ago': 32,
#          'indistinct': 1,
#          'remembrance': 8,
#          'caresses': 1,
#          'place': 93,
#          'supplied': 5,
#          'excellent': 34,
#          'woman': 131,
#          'governess': 9,
#          'fallen': 7,
#          'short': 70,
#          'affection': 50,
#          'sixteen': 9,
#          'miss': 599,
#          'taylor': 48,
#          'mr': 1153,
#          'family': 77,
#          'less': 68,
#          'friend': 177,
#          'fond': 39,
#          'particularly': 46,
#          'intimacy': 21,
#          'sisters': 12,
#          'even': 132,
#          'ceased': 6,
#          'hold': 14,
#          'nominal': 1,
#          'office': 16,
#          'mildness': 1,
#          'temper': 36,
#          'hardly': 71,
#          'allowed': 40,
#          'impose': 1,
#          'restraint': 3,
#          'shadow': 2,
#          'authority': 6,
#          'passed': 55,
#          'away': 138,
#          'living': 18,
#          'together': 81,
#          'mutually': 3,
#          'attached': 25,
#          'liked': 16,
#          'highly': 24,
#          'esteeming': 1,
#          'judgment': 29,
#          'directed': 6,
#          'chiefly': 7,
#          'real': 42,
#          'evils': 10,
#          'indeed': 202,
#          'situation': 64,
#          'power': 41,
#          'rather': 146,
#          'much': 486,
#          'way': 155,
#          'think': 383,
#          'well': 401,
#          'disadvantages': 1,
#          'threatened': 4,
#          'alloy': 3,
#          'many': 138,
#          'enjoyments': 3,
#          'danger': 31,
#          'however': 131,
#          'present': 89,
#          'unperceived': 2,
#          'means': 48,
#          'rank': 9,
#          'misfortunes': 1,
#          'sorrow': 4,
#          'came': 119,
#          'gentle': 16,
#          'shape': 5,
#          'disagreeable': 20,
#          'consciousness': 21,
#          'married': 45,
#          'loss': 23,
#          'first': 209,
#          'brought': 54,
#          'grief': 5,
#          'wedding': 17,
#          'day': 192,
#          'beloved': 9,
#          'sat': 37,
#          'mournful': 1,
#          'thought': 226,
#          'continuance': 2,
#          'bride': 13,
#          'people': 95,
#          'gone': 80,
#          'left': 68,
#          'dine': 15,
#          'prospect': 13,
#          'third': 5,
#          'cheer': 4,
#          'evening': 96,
#          'composed': 6,
#          'sleep': 2,
#          'dinner': 49,
#          'usual': 51,
#          'sit': 38,
#          'lost': 21,
#          'event': 24,
#          'every': 435,
#          'promise': 21,
#          'happiness': 76,
#          'weston': 440,
#          'man': 235,
#          'unexceptionable': 7,
#          'character': 43,
#          'easy': 28,
#          'fortune': 39,
#          'suitable': 4,
#          'age': 22,
#          'pleasant': 41,
#          'manners': 53,
#          'satisfaction': 28,
#          'considering': 20,
#          'self': 23,
#          'denying': 7,
#          'generous': 4,
#          'friendship': 26,
#          'always': 238,
#          'wished': 48,
#          'promoted': 4,
#          'match': 32,
#          'black': 5,
#          'morning': 111,
#          'work': 22,
#          'want': 90,
#          'would': 820,
#          'felt': 113,
#          'hour': 83,
#          'recalled': 2,
#          'past': 20,
#          'kindness': 40,
#          'taught': 7,
#          'played': 8,
#          'five': 42,
#          'old': 85,
#          'devoted': 5,
#          'powers': 14,
#          'attach': 5,
#          'amuse': 8,
#          'health': 39,
#          'nursed': 3,
#          'various': 6,
#          'illnesses': 3,
#          'childhood': 2,
#          'large': 35,
#          'debt': 1,
#          'gratitude': 29,
#          'owing': 3,
#          'intercourse': 12,
#          'last': 119,
#          'seven': 8,
#          'equal': 57,
#          'footing': 3,
#          'perfect': 34,
#          'unreserve': 6,
#          'soon': 224,
#          'followed': 29,
#          'isabella': 69,
#          'yet': 109,
#          'dearer': 6,
#          'tenderer': 1,
#          'recollection': 8,
#          'companion': 27,
#          'possessed': 3,
#          'intelligent': 4,
#          'informed': 5,
#          'useful': 21,
#          'knowing': 26,
#          'ways': 16,
#          'interested': 15,
#          'concerns': 9,
#          'peculiarly': 11,
#          'pleasure': 115,
#          'scheme': 23,
#          'could': 837,
#          'speak': 99,
#          'arose': 4,
#          'never': 358,
#          'find': 75,
#          'fault': 20,
#          'bear': 52,
#          'change': 61,
#          'true': 66,
#          'going': 120,
#          'half': 118,
#          'mile': 11,
#          'aware': 26,
#          'great': 264,
#          'must': 567,
#          'difference': 31,
#          'mrs': 699,
#          'advantages': 12,
#          'natural': 52,
#          'domestic': 7,
#          'suffering': 16,
#          'intellectual': 3,
#          'solitude': 3,
#          'dearly': 2,
#          'loved': 27,
#          'meet': 32,
#          'conversation': 42,
#          'rational': 18,
#          'playful': 2,
#          'evil': 33,
#          'actual': 3,
#          'disparity': 7,
#          'ages': 2,
#          'increased': 12,
#          'constitution': 7,
#          'habits': 12,
#          'valetudinarian': 1,
#          'life': 80,
#          'without': 214,
#          'activity': 4,
#          'mind': 128,
#          'body': 193,
#          'older': 8,
#          'though': 177,
#          'everywhere': 3,
#          'friendliness': 3,
#          'heart': 66,
#          'amiable': 35,
#          'talents': 8,
#          'recommended': 9,
#          'time': 279,
#          'comparatively': 2,
#          'removed': 10,
#          'matrimony': 8,
#          'settled': 39,
#          'london': 45,
#          'miles': 17,
#          'beyond': 54,
#          'daily': 10,
#          'reach': 7,
#          'october': 4,
#          'november': 5,
#          'struggled': 2,
#          'hartfield': 160,
#          'christmas': 11,
#          'next': 63,
#          'visit': 86,
#          'husband': 34,
#          'children': 60,
#          'fill': 2,
#          'give': 159,
#          'society': 48,
#          'highbury': 125,
#          'populous': 2,
#          'village': 2,
#          'almost': 88,
#          'amounting': 1,
#          'town': 23,
#          'spite': 24,
#          'separate': 12,
#          'lawn': 4,
#          'shrubberies': 2,
#          'name': 56,
#          'really': 153,
#          'belong': 15,
#          'afforded': 8,
#          'equals': 1,
#          'woodhouses': 4,
#          'looked': 91,
#          'acquaintance': 63,
#          'universally': 4,
#          'civil': 13,
#          'among': 51,
#          'accepted': 10,
#          'lieu': 1,
#          'melancholy': 12,
#          'sigh': 19,
#          'wish': 135,
#          'impossible': 41,
#          'things': 62,
#          'till': 102,
#          'awoke': 1,
#          'made': 199,
#          'necessary': 36,
#          'cheerful': 29,
#          'spirits': 64,
#          'required': 14,
#          'support': 8,
#          'nervous': 11,
#          'easily': 14,
#          'depressed': 6,
#          'used': 50,
#          'hating': 2,
#          'part': 70,
#          'kind': 82,
#          'origin': 4,
#          'reconciled': 8,
#          'daughter': 62,
#          'marrying': 26,
#          'ever': 193,
#          'compassion': 13,
#          'entirely': 39,
#          'obliged': 76,
#          'selfishness': 4,
#          'able': 72,
#          'suppose': 81,
#          'feel': 95,
#          'differently': 11,
#          'disposed': 21,
#          'done': 142,
#          'sad': 25,
#          'thing': 398,
#          'deal': 92,
#          'happier': 11,
#          'spent': 21,
#          'rest': 50,
#          'smiled': 17,
#          'chatted': 1,
#          'cheerfully': 8,
#          'keep': 33,
#          'thoughts': 38,
#          'tea': 27,
#          'say': 310,
#          'exactly': 58,
#          'said': 484,
#          'poor': 136,
#          'pity': 26,
#          'agree': 15,
#          'papa': 33,
#          'know': 337,
#          'good': 358,
#          'humoured': 6,
#          'thoroughly': 19,
#          'deserves': 6,
#          'wife': 68,
#          'live': 17,
#          'us': 145,
#          'odd': 26,
#          'humours': 2,
#          'might': 326,
#          'advantage': 27,
#          'three': 72,
#          'times': 28,
#          'dear': 241,
#          'often': 91,
#          'shall': 217,
#          'see': 222,
#          'coming': 89,
#          'meeting': 39,
#          'begin': 31,
#          'go': 132,
#          'pay': 25,
#          'get': 67,
#          'far': 70,
#          'randalls': 90,
#          'distance': 25,
#          'walk': 56,
#          'nobody': 73,
#          'walking': 45,
#          'carriage': 69,
#          'sure': 204,
#          'james': 19,
#          'like': 200,
#          'put': 64,
#          'horses': 25,
#          'paying': 11,
#          'stable': 2,
#          'already': 45,
#          'talked': 66,
#          'night': 41,
#          'may': 221,
#          'housemaid': 1,
#          'doubt': 98,
#          'whether': 64,
#          'take': 119,
#          'anywhere': 16,
#          'else': 80,
#          'got': 36,
#          'hannah': 2,
#          'mentioned': 26,
#          'glad': 50,
#          'lucky': 10,
#          'slighted': 6,
#          'upon': 159,
#          'account': 59,
#          'make': 152,
#          'servant': 6,
#          'pretty': 68,
#          'spoken': 31,
#          'girl': 47,
#          'opinion': 71,
#          'whenever': 28,
#          'curtseys': 1,
#          'asks': 3,
#          'manner': 75,
#          'needlework': 1,
#          'observe': 23,
#          'turns': 9,
#          'lock': 1,
#          'door': 47,
#          'right': 92,
#          'bangs': 1,
#          'comfort': 65,
#          'somebody': 16,
#          'goes': 6,
#          'hearing': 32,
#          'tell': 77,
#          'spared': 7,
#          'exertions': 6,
#          'maintain': 4,
#          'flow': 6,
#          'ideas': 16,
#          'hoped': 43,
#          'help': 39,
#          'backgammon': 3,
#          'tolerably': 15,
#          'attacked': 2,
#          'regrets': 6,
#          'table': 27,
#          'placed': 15,
#          'visitor': 9,
#          'immediately': 70,
#          'afterwards': 41,
#          'walked': 52,
#          'unnecessary': 8,
#          'knightley': 389,
#          'sensible': 25,
#          'eight': 7,
#          'thirty': 5,
#          'intimate': 10,
#          'connected': 11,
#          'elder': 4,
#          'brother': 55,
#          'frequent': 8,
#          'welcome': 16,
#          'directly': 51,
#          'mutual': 5,
#          'connexions': 10,
#          'returned': 39,
#          'late': 27,
#          'days': 50,
#          'absence': 15,
#          'brunswick': 11,
#          'square': 12,
#          'circumstance': 34,
#          'animated': 5,
#          'inquiries': 10,
#          'answered': 22,
#          'satisfactorily': 2,
#          'gratefully': 5,
#          'observed': 22,
#          'come': 172,
#          'call': 42,
#          'afraid': 65,
#          'shocking': 6,
#          'sir': 66,
#          'beautiful': 24,
#          'moonlight': 2,
#          'mild': 4,
#          'draw': 10,
#          'back': 67,
#          'fire': 16,
#          'found': 92,
#          'damp': 6,
#          'dirty': 6,
#          'catch': 14,
#          'cold': 54,
#          'look': 121,
#          'shoes': 4,
#          'speck': 1,
#          'quite': 282,
#          'surprising': 2,
#          'vast': 6,
#          'rain': 22,
#          'rained': 1,
#          'dreadfully': 8,
#          'hard': 12,
#          'breakfast': 12,
#          'wanted': 75,
#          'bye': 12,
#          'joy': 18,
#          'sort': 112,
#          'feeling': 56,
#          'hurry': 24,
#          'congratulations': 7,
#          'hope': 143,
#          'went': 46,
#          'behave': 3,
#          'cried': 81,
#          'ah': 48,
#          'tis': 2,
#          'business': 55,
#          'please': 35,
#          'possibly': 17,
#          'regard': 43,
#          'comes': 24,
#          'question': 39,
#          'dependence': 11,
#          'independence': 11,
#          'rate': 18,
#          'better': 173,
#          'especially': 25,
#          'fanciful': 3,
#          'troublesome': 9,
#          'creature': 39,
#          'playfully': 2,
#          'head': 40,
#          'certainly': 101,
#          'believe': 102,
#          'sometimes': 39,
#          'dearest': 20,
#          'mean': 59,
#          'horrible': 5,
#          'idea': 100,
#          'oh': 193,
#          'meant': 43,
#          'loves': 9,
#          'joke': 6,
#          'another': 114,
#          'fact': 24,
#          'faults': 11,
#          'told': 78,
#          'agreeable': 50,
#          'knew': 88,
#          'suspect': 21,
#          'knows': 30,
#          'flatter': 5,
#          'reflection': 18,
#          'persons': 11,
#          'chances': 5,
#          'gainer': 1,
#          'willing': 13,
#          'let': 90,
#          'pass': 32,
#          'hear': 100,
#          'behaved': 11,
#          'charmingly': 4,
#          'punctual': 1,
#          'looks': 29,
#          'tear': 4,
#          'face': 32,
#          'seen': 73,
#          'apart': 3,
#          'bears': 2,
#          'sorry': 61,
#          'lose': 19,
#          'thinks': 23,
#          'turned': 29,
#          'divided': 4,
#          'tears': 9,
#          'smiles': 15,
#          'acceptable': 8,
#          'important': 20,
#          'secure': 9,
#          'provision': 3,
#          'therefore': 62,
#          'allow': 47,
#          'pain': 34,
#          'happily': 18,
#          'forgotten': 19,
#          'matter': 32,
#          'considerable': 17,
#          'four': 30,
#          'proved': 16,
#          'marry': 63,
#          'shook': 8,
#          'fondly': 4,
#          'replied': 79,
#          'matches': 6,
#          'foretell': 2,
#          'whatever': 20,
#          'pray': 26,
#          'none': 29,
#          'greatest': 29,
#          'amusement': 16,
#          'success': 11,
#          'widower': 2,
#          'perfectly': 67,
#          'constantly': 8,
#          'occupied': 16,
#          'either': 64,
#          'friends': 82,
#          'wherever': 7,
#          'need': 42,
#          'spend': 18,
#          'single': 19,
#          'year': 28,
#          'alone': 27,
#          'deathbed': 1,
#          'others': 60,
#          'son': 47,
#          'uncle': 23,
#          'letting': 3,
#          'solemn': 5,
#          'nonsense': 20,
#          'subject': 97,
#          'believed': 46,
#          'since': 65,
#          'met': 38,
#          'broadway': 1,
#          'lane': 11,
#          'began': 64,
#          'drizzle': 1,
#          'darted': 3,
#          'gallantry': 12,
#          'borrowed': 2,
#          'umbrellas': 2,
#          'farmer': 9,
#          'mitchell': 1,
#          'planned': 2,
#          'blessed': 7,
#          'instance': 9,
#          'leave': 58,
#          'making': 57,
#          'understand': 68,
#          'supposes': 1,
#          'endeavour': 14,
#          'properly': 10,
#          'delicately': 1,
#          'endeavouring': 3,
#          'bring': 38,
#          'worthy': 18,
#          'employment': 10,
#          'young': 192,
#          'lady': 73,
#          'imagine': 55,
#          'planning': 3,
#          'saying': 51,
#          'idle': 4,
#          'talk': 60,
#          'merit': 14,
#          'proud': 8,
#          'guess': 25,
#          'known': 60,
#          'triumph': 6,
#          'cleverer': 3,
#          'depend': 26,
#          'merely': 29,
#          'luck': 11,
#          'talent': 9,
#          'word': 94,
#          'quarrel': 11,
#          'claim': 12,
#          'drawn': 15,
#          'pictures': 2,
#          'something': 113,
#          'nothing': 256,
#          'visits': 14,
#          'given': 77,
#          'encouragements': 1,
#          'smoothed': 2,
#          'matters': 10,
#          'enough': 129,
#          'comprehend': 15,
#          'straightforward': 3,
#          'open': 41,
#          'hearted': 13,
#          'unaffected': 4,
#          'safely': 19,
#          'manage': 5,
#          'likely': 46,
#          'harm': 13,
#          'interference': 8,
#          'rejoined': 2,
#          'understanding': 28,
#          'silly': 12,
#          'break': 13,
#          'circle': 18,
#          'grievously': 1,
#          'elton': 385,
#          'whole': 76,
#          'fitted': 1,
#          'comfortably': 11,
#          'shame': 9,
#          'longer': 59,
#          'joining': 2,
#          'hands': 23,
#          'service': 23,
#          'shew': 28,
#          'attention': 59,
#          'ask': 43,
#          'dare': 59,
#          'laughing': 17,
#          'invite': 13,
#          'fish': 2,
#          'chicken': 2,
#          'chuse': 24,
#          'six': 12,
#          'care': 51,
#          'ii': 4,
#          'native': 5,
#          'born': 6,
#          'respectable': 20,
#          'generations': 2,
#          'rising': 6,
#          'gentility': 6,
#          'property': 6,
#          'received': 36,
#          'education': 16,
#          'succeeding': 5,
#          'small': 31,
#          'become': 12,
#          'indisposed': 3,
#          'homely': 1,
#          'pursuits': 2,
#          'brothers': 4,
#          'engaged': 38,
#          'satisfied': 52,
#          'active': 7,
#          'social': 6,
#          'entering': 8,
#          'militia': 2,
#          'county': 2,
#          'embodied': 1,
#          'captain': 3,
#          'general': 65,
#          'favourite': 23,
#          'military': 1,
#          'introduced': 8,
#          'churchill': 224,
#          'yorkshire': 8,
#          'fell': 10,
#          'love': 117,
#          'surprized': 32,
#          'except': 32,
#          'full': 46,
#          'pride': 18,
#          'importance': 12,
#          'connexion': 20,
#          'offend': 3,
#          'command': 22,
#          'bore': 7,
#          'proportion': 4,
#          'estate': 4,
#          'dissuaded': 1,
#          'took': 47,
#          'infinite': 3,
#          'mortification': 11,
#          'threw': 2,
#          'due': 23,
#          'decorum': 2,
#          'unsuitable': 3,
#          'produce': 10,
#          'ought': 95,
#          'whose': 39,
#          'warm': 30,
#          'sweet': 22,
#          'return': 56,
#          'goodness': 7,
#          'spirit': 27,
#          'resolution': 31,
#          'pursue': 1,
#          'refrain': 5,
#          'unreasonable': 9,
#          'anger': 7,
#          'missing': 3,
#          'luxuries': 1,
#          'former': 14,
#          'income': 10,
#          'still': 115,
#          'comparison': 11,
#          'enscombe': 36,
#          'cease': 7,
#          'considered': 19,
#          'churchills': 15,
#          'amazing': 4,
#          'worst': 19,
#          'bargain': 2,
#          'poorer': 1,
#          'child': 38,
#          'expense': 7,
#          'relieved': 5,
#          'boy': 13,
#          'additional': 4,
#          'softening': 2,
#          'lingering': 1,
#          'illness': 9,
#          'reconciliation': 3,
#          'kindred': 1,
#          'offered': 8,
#          'charge': 18,
#          'frank': 208,
#          'decease': 2,
#          'scruples': 10,
#          'reluctance': 3,
#          'supposed': 35,
#          'overcome': 9,
#          'considerations': 2,
#          'wealth': 7,
#          'seek': 6,
#          'improve': 7,
#          'complete': 20,
#          'became': 23,
#          'desirable': 18,
#          'quitted': 9,
#          'trade': 7,
#          'established': 5,
#          'favourable': 14,
#          'opening': 15,
#          'concern': 18,
#          'leisure': 13,
#          'occupation': 4,
#          'pleasures': 9,
#          'eighteen': 4,
#          'realised': 2,
#          'competence': 1,
#          'purchase': 6,
#          'adjoining': 6,
#          'longed': 6,
#          'portionless': 1,
#          'according': 5,
#          'wishes': 20,
#          'friendly': 18,
#          'begun': 12,
#          'influence': 24,
#          'schemes': 7,
#          'tyrannic': 1,
#          'youth': 11,
#          'shaken': 6,
#          'determination': 5,
#          'settling': 4,
#          'sale': 2,
#          'forward': 36,
#          'steadily': 5,
#          'objects': 7,
#          'view': 27,
#          'accomplished': 11,
#          'bought': 4,
#          'obtained': 5,
#          'beginning': 40,
#          'new': 36,
#          'probability': 12,
#          'greater': 29,
#          'unhappy': 19,
#          'secured': 11,
#          'second': 31,
#          'delightful': 41,
#          'judging': 11,
#          'truly': 12,
#          'pleasantest': 3,
#          'proof': 23,
#          'choose': 1,
#          'chosen': 15,
#          'excite': 3,
#          'choice': 9,
#          'tacitly': 2,
#          'heir': 3,
#          'avowed': 1,
#          'adoption': 1,
#          'assume': 1,
#          'unlikely': 4,
#          'assistance': 14,
#          'apprehension': 7,
#          'aunt': 57,
#          'capricious': 1,
#          'governed': 2,
#          'nature': 41,
#          'caprice': 3,
#          'strong': 44,
#          'affect': 5,
#          'deservedly': 2,
#          'saw': 108,
#          'report': 10,
#          'fine': 42,
#          'sufficiently': 9,
#          'belonging': 4,
#          'merits': 7,
#          'prospects': 8,
#          'common': 35,
#          'boasts': 1,
#          'lively': 12,
#          'curiosity': 28,
#          'prevailed': 6,
#          'compliment': 31,
#          'achieved': 2,
#          'generally': 24,
#          'proposed': 14,
#          'proper': 42,
#          'dissentient': 1,
#          'voice': 47,
#          'perry': 80,
#          'drank': 2,
#          'bates': 148,
#          'strengthened': 4,
#          'understood': 23,
#          'written': 24,
#          'occasion': 28,
#          'included': 5,
#          'mention': 19,
#          'letter': 109,
#          'heard': 120,
#          'says': 31,
#          'prized': 1,
#          'course': 61,
#          'formed': 12,
#          'pleasing': 22,
#          'irresistible': 5,
#          'sense': 56,
#          'addition': 10,
#          'source': 7,
#          'expression': 9,
#          'congratulation': 2,
#          'fortunate': 27,
#          'regret': 26,
#          'partial': 7,
#          'separation': 4,
#          'cooled': 2,
#          'ill': 73,
#          'missed': 8,
#          'losing': 5,
#          'ennui': 1,
#          'companionableness': 1,
#          'feeble': 1,
#          'girls': 13,
#          'energy': 3,
#          'difficulties': 17,
#          'privations': 4,
#          'convenient': 5,
#          'solitary': 3,
#          'female': 7,
#          'circumstances': 31,
#          'approaching': 7,
#          'season': 6,
#          'hindrance': 1,
#          'spending': 5,
#          'evenings': 5,
#          'week': 29,
#          'altogether': 23,
#          'hours': 25,
#          'moments': 12,
#          'enjoyment': 22,
#          'apparent': 10,
#          'taken': 58,
#          'surprize': 37,
#          'centre': 3,
#          'attended': 9,
#          'giving': 46,
#          'stay': 44,
#          'recovering': 4,
#          'likelihood': 2,
#          'ceasing': 1,
#          'weeks': 21,
#          'alleviation': 2,
#          'compliments': 15,
#          'neighbours': 16,
#          'teased': 1,
#          'sorrowful': 5,
#          'cake': 8,
#          'eat': 12,
#          'stomach': 2,
#          'different': 42,
#          'unwholesome': 5,
#          'regarded': 4,
#          'unfit': 4,
#          'earnestly': 12,
#          'tried': 26,
#          'dissuade': 3,
#          ...})

# %%
from wordcloud import WordCloud
# generate a word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white', 
                      stopwords=stop_words, min_font_size=10).generate_from_frequencies(word_counts)

# plot the WordCloud image                        
plt.figure(figsize=(8, 8), facecolor=None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad=0) 
plt.show()

# %% [markdown]
# #2)Frequent Word Detection:

# %%
import nltk
from collections import Counter

# load the corpus dataset
nltk.download('gutenberg')
corpus = nltk.corpus.gutenberg

# tokenize the text data
text = " ".join(corpus.words())
tokens = nltk.word_tokenize(text)

# remove stop words and punctuation marks
stop_words = set(nltk.corpus.stopwords.words('english'))
tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

# count the frequency of each word
word_counts = Counter(tokens)

# sort the words based on their frequency
sorted_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

# print the top 10 most frequent words
for word, freq in sorted_words[:10]:
    print(f"{word}: {freq}")
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# shall: 11682
# said: 9429
# unto: 9010
# lord: 8590
# thou: 6759
# one: 6218
# man: 5615
# thy: 5609
# god: 5287
# thee: 4807

# %% [markdown]
# #3)Keyword Extraction based on Ranking

# %%
# !pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.9/dist-packages (from rake-nltk) (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.1)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
import nltk
from rake_nltk import Rake
from nltk.corpus import stopwords

# load the corpus dataset
nltk.download('gutenberg')
corpus = nltk.corpus.gutenberg

# tokenize the text data
text = " ".join(corpus.words())

# remove stop words and punctuation marks
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %% [markdown]
# #Rapid Keyword Extraction (RAKE)
# * RAKE is a Domain-Independent keyword extraction algorithm in Natural Language Processing.
#
# * It is an Individual document-oriented dynamic Information retrieval method.
#
# * Concept of RAKE is built on three matrices Word Degree (deg(w)), Word Frequency (freq(w)), Ratio of the degree to frequency (deg(w)/freq(w)).

# %% [markdown]
# Once we have the text corpus, RAKE splits the text into a list of words, removing stop words from the same list. Return list is known as Content Words.
#
# Content_Word= Corpus – [Stopwords , Delimiter]
#
# Detailed explanation is available at https://www.analyticsvidhya.com/blog/2021/10/rapid-keyword-extraction-rake-algorithm-in-natural-language-processing/

# %%
# generate a list of keywords using RAKE
r = Rake(stopwords=stop_words)
r.extract_keywords_from_text(text)
keywords = r.get_ranked_phrases()

# print the top 10 keywords
print(keywords[:10])
# Out:
# ['progress (* means estimated ): ebooks year month 1 1971 july 10 1991 january 100 1994 january 1000 1997 august 1500 1998 october 2000 1999 december 2500 2000 december 3000 2001 november 4000 2001 october', '.-- _she_ _felt_ _the_ _engagement_ _to_ _be_ _a_ _source_ _of_ _repentance_ _and_ _misery_ _to_ _each_', 'tutte le gran faciende si fanno di poca cosa', 'mais pas plus fin que tous les autres ."', 'toute leur etude etait de se complaire et de', 'pagens ont tort et chretiens ont droit ."', 'la vita il fine ,-- e di loda la sera', 'la mala compagnia e quella che mena uomini', 'project gutenberg literary archive foundation pmb 113 1739 university ave', 'strong hymn eine feste burg ist unser gott']

# %% [markdown]
# #4)Dictionary Building

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import nltk
from nltk.corpus import wordnet as wn

# load the corpus dataset
nltk.download('gutenberg')
corpus = nltk.corpus.gutenberg

# tokenize the text data
text = " ".join(corpus.words())
tokens = nltk.word_tokenize(text)

# remove stop words and punctuation marks
stop_words = set(stopwords.words('english'))
tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

# identify the parts of speech for each word
pos_tags = nltk.pos_tag(tokens)

# create a list of words with their definitions using WordNet
dictionary = {}
for word, tag in pos_tags:
    synsets = wn.synsets(word)
    if synsets:
        definition = synsets[0].definition()
        dictionary[word] = definition

# print the dictionary
for word, definition in dictionary.items():
    print(f"{word}: {definition}")
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Streaming output truncated to the last 5000 lines.
# detestation: hate coupled with disgust
# ignoramus: an ignorant person
# satirizing: ridicule with satire
# conjures: summon into action or bring into existence, often as if by magic
# confining: place limits on (extent or access)
# diddled: deprive of by deceit
# bordeaux: a port city in southwestern France; a major center of the wine trade
# slacking: the evasion of work or duty
# excavation: the act of digging
# pottery: ceramic ware made from clay and baked in a kiln
# loam: a rich soil consisting of a mixture of sand and clay and decaying organic materials
# dent: an appreciable consequence (especially a lessening)
# druggist: a health professional trained in the art of preparing and dispensing drugs
# soils: the state of being covered with unclean things
# odorless: having no odor
# waxy: made of or covered with wax
# perfumery: perfumes in general
# pomatum: hairdressing consisting of a perfumed oil or ointment
# grains: a relatively small granular particle of a substance
# inglorious: (used of conduct or character) deserving or bringing disgrace or shame; - Rachel Carson
# paracelsus: Swiss physician who introduced treatments of particular illnesses based on his observation and experience; he saw illness as having an external cause (rather than an imbalance of humors) and replaced traditional remedies with chemical remedies (1493-1541)
# manufacturing: the act of making something (a product) from raw materials
# slanderous: (used of statements) harmful and often untrue; tending to discredit or malign
# disproved: prove to be false
# slatternly: characteristic of or befitting a slut or slattern; used especially of women
# stigma: the apical end of the style where deposited pollen enters the pistil
# bung: a plug used to close a hole in a barrel or flask
# unloading: the labor of taking a load of something off of or out of a vehicle or ship or container etc.
# cemeteries: a tract of land used for burials
# excavating: recover through digging
# imports: commodities (goods or services) bought from a foreign country
# berg: a large mass of ice floating at sea; usually broken off of a polar glacier
# sheds: an outbuilding with a single story; used for shelter or storage
# scentless: lacking the sense of smell
# dispenses: administer or bestow, as in small portions
# rustles: a light noise, like the noise of silk clothing or leaves blowing in the wind
# redolent: serving to bring to mind; - Wilder Hobson
# timorous: timid by nature or revealing timidity
# pippin: any of numerous superior eating apples with yellow or greenish yellow skin flushed with red
# developments: act of improving by expanding or enlarging or refining
# torpid: slow and apathetic
# calendar: a system of timekeeping that defines the beginning and length and divisions of the year
# julys: the month following June and preceding August
# luridly: in a lurid manner
# fictitiously: in a false manner intended to mislead
# fiddler: a musician who plays the violin
# belled: attach a bell to
# veined: make a veinlike pattern
# jeweller: someone who makes jewelry
# effulgences: the quality of being bright and sending out rays of light
# divinest: emanating from God; ; ; -Saturday Review
# discreditably: in a dishonorable manner or to a dishonorable degree
# courageousness: a quality of spirit that enables you to face danger or pain without showing fear
# breasted: meet at breast level
# interrogatively: in a questioning format
# execrations: hate coupled with disgust
# evaporate: lose or cause to lose liquid by vaporization leaving a more concentrated residue
# officially: in an official role
# unofficially: without official authorization
# undiluted: not diluted
# interferes: come between so as to be hindrance or obstacle
# bounteous: given or giving freely
# flatly: in an unqualified manner
# ebon: of a very dark black
# cloves: aromatic flower bud of a clove tree; yields a spice
# lonesomeness: a disposition toward being alone
# immensity: unusual largeness in size or extent or number
# hug: a tight or amorous embrace
# jeopardized: pose a threat to; present a danger to
# jeeringly: in a disrespectful jeering manner
# eternities: time without end
# treadle: a lever that is operated with the foot
# weal: a raised mark on the skin (as produced by the blow of a whip); characteristic of many allergic reactions
# crystallized: cause to take on a definite and clear shape
# constantine: Emperor of Rome who stopped the persecution of Christians and in 324 made Christianity the official religion of the Roman Empire; in 330 he moved his capital from Rome to Byzantium and renamed it Constantinople (280-337)
# concreted: cover with cement
# sweetener: something added to foods to make them taste sweeter
# globules: a small globe or ball
# tissues: part of an organism consisting of an aggregate of cells having a similar structure and function
# opulence: wealth as evidenced by sumptuous living
# uncontaminated: not corrupted by contact or association
# aroma: any property detected by the olfactory system
# allaying: lessen the intensity of or calm
# divinely: by divine means
# acerbities: a sharp bitterness
# discoursing: to consider or examine in speech or writing
# behooves: be appropriate or necessary
# muscle: one of the contractile organs of the body
# mincer: a kitchen utensil that cuts or chops food (especially meat) into small pieces
# berkshire: a county in southern England
# participating: share in something
# citron: large lemonlike fruit with thick aromatic rind; usually preserved
# cutlet: thin slice of meat (especially veal) usually fried or broiled
# ineffably: to an inexpressible degree
# decanting: pour out
# ruptured: separate or cause to separate abruptly
# membranes: a thin pliable sheet of material
# coalescing: mix together different elements
# designates: assign a name or title to
# glutinous: having the sticky properties of an adhesive
# nippers: a young person of either sex
# indigenous: originating where it is found
# vocabulary: a listing of the words used in some enterprise
# nipper: a young person of either sex
# edgewise: with the edge forward or on, by, or toward the edge
# operates: direct or control; projects, businesses, etc.
# squilgee: wipe with a squeegee
# allures: the power to entice or attract through personal charm
# impurities: worthless or dangerous material that should be removed
# tyros: someone new to a field or activity
# gaff: a sharp metal spike or spur that is fastened to the leg of a gamecock
# lurches: an unsteady uneven gait
# hone: a whetstone made of fine gritstone; used for sharpening razors
# shoeless: without shoes
# scanned: examine minutely or intensely
# scuppers: drain that allows water on the deck of a vessel to flow overboard
# kentuckian: a native or resident of Kentucky
# depose: force to leave (an office)
# pelt: the dressed hairy coat of a mammal
# boa: a long thin fluffy scarf of feathers or fur
# pantaloon: a buffoon in modern pantomimes; the butt of jokes
# slits: a long narrow opening
# endwise: on end or upright
# rapt: feeling great rapture or delight
# archbishopric: the territorial jurisdiction of an archbishop
# enjoins: issue an injunction
# accelerated: move faster
# constituting: form or compose
# roomy: an associate who shares a room with you
# battened: furnish with battens
# soapstone: a soft heavy compact variety of talc having a soapy feel; used to make hearths and tabletops and ornaments
# geometry: the pure mathematics of points and lines and curves and surfaces
# cycloid: a line generated by a point on a circle rolling along a straight line
# evaporates: lose or cause to lose liquid by vaporization leaving a more concentrated residue
# ignition: the process of initiating combustion or catching fire
# properties: something owned; any tangible or intangible possession that is owned by someone
# plethoric: excessively abundant
# misanthrope: someone who dislikes people in general
# pyres: wood heaped for burning a dead body as a funeral rite
# flues: flat bladelike projection on the arm of an anchor
# frigates: a medium size square-rigged warship of the 18th and 19th centuries
# conflagrations: a very intense and uncontrolled fire
# tartarean: of or relating to or characteristic of Hades or Tartarus
# stokers: Irish writer of the horror novel about Dracula (1847-1912)
# pronged: having prongs or tines; usually used in combination
# begrimed: make soiled, filthy, or dirty
# emblazonings: decorate with colors
# gesticulated: show, express or direct through movement
# dippers: a Baptist denomination founded in 1708 by Americans of German descent; opposed to military service and taking legal oaths; practiced trine immersion
# champed: chafe at the bit, like horses
# ghastliness: the quality of being ghastly
# fatally: with fatal consequences or implications
# illuminating: make lighter or brighter
# hallucination: illusory perception; a common symptom of severe mental disorder
# hitching: to hook or entangle
# forking: the place where something divides into branches
# gentler: soft and mild; not harsh or stern or severe
# sahara: the world's largest desert (3,500,000 square miles) in northern Africa
# unchristian: not of a Christian faith
# jails: a correctional institution used to detain persons who are in the lawful custody of the government (either accused persons awaiting trial or convicted persons serving a sentence)
# graveyards: a tract of land used for burials
# operas: a drama set to music; consists of singing with orchestral accompaniment and an orchestral overture and interludes
# pascal: a unit of pressure equal to one newton per square meter
# rousseau: French philosopher and writer born in Switzerland; believed that the natural goodness of man was warped by society; ideas influenced the French Revolution (1712-1778)
# invert: make an inversion (in a musical composition)
# deaden: make vague or obscure or make (an image) less visible
# soar: the act of rising upward into the air
# swoop: (music) rapid sliding up or down the musical scale
# canonized: declare (a dead person) to be a saint
# pallet: the range of colour characteristic of a particular artist or painting or school of art
# pitchiest: of the blackest black; similar to the color of jet or coal
# replenishes: fill something that had previously been emptied
# vat: a tax levied on the difference between a commodity's price before taxes and its cost of production
# astral: being or relating to or resembling or emanating from stars
# genuineness: the state of being genuine
# moors: one of the Muslim people of north Africa; of mixed Arab and Berber descent; converted to Islam in the 8th century; conqueror of Spain in the 8th century
# unscathed: not injured
# unsealed: break the seal of
# hermetically: in an airtight manner
# freshets: the occurrence of a water flow resulting from sudden rain or melting snow
# brewery: a plant where beer is brewed by fermentation
# suffused: cause to spread or flush or flood through, over, or across
# adhesiveness: the property of sticking together (as of glue and wood) or the joining of surfaces of different composition
# exterminates: kill en masse; kill on a large scale; kill many
# scrubbed: clean with hard rubbing
# aglow: softly bright or radiant
# bridegrooms: a man who has recently been married
# cambrics: a finely woven white linen
# sweatings: the process of the sweat glands of the skin secreting a salty fluid
# toilings: work hard
# metempsychosis: after death the soul begins a new cycle of existence in another human body
# pythagoras: Greek philosopher and mathematician who proved the Pythagorean theorem; considered to be the first true mathematician (circa 580-500 BC)
# doubloon: a former Spanish gold coin
# hopefulness: full of hope
# cartload: the quantity that a cart holds
# morass: a soft wet area of low-lying land that sinks underfoot
# rustiness: the condition of being coated or clogged with rust
# verdigris: a blue or green powder used as a paint pigment
# untouchable: belongs to lowest social and ritual class in India
# foulness: disgusting wickedness and immorality
# revered: love unquestioningly and uncritically or to excess; venerate as an idol
# talisman: a trinket or piece of jewelry usually hung about the neck and thought to be a magical protection against evil or disease
# alpacas: wool of the alpaca
# volcanoes: a fissure in the earth's crust (or in the surface of some other planet) through which molten lava and gases erupt
# disks: something with a round shape resembling a flat circular plate
# ecliptics: the great circle representing the apparent annual path of the sun; the plane of the Earth's orbit around the sun; makes an angle of about 23 degrees with the equator
# preciousness: the quality possessed by something with a great price or value
# enhancing: increase
# mints: (often followed by `of') a large number or amount or extent
# ecuador: a republic in northwestern South America; became independent from Spain in 1822; the landscape is dominated by the Andes
# crowing: an instance of boastful talk
# partitioned: divide into parts, pieces, or sections
# keystone: a central cohesive source of support and stability
# equinoctial: the great circle on the celestial sphere midway between the celestial poles
# libra: (astrology) a person who is born while the sun is in Libra
# equinox: either of two times of the year when the sun crosses the plane of the earth's equator and day and night are of equal length
# aries: (astrology) a person who is born while the sun is in Aries
# trinity: the cardinal number that is the sum of one and one and one
# girds: prepare oneself for a military confrontation
# fixture: an object firmly fixed in place (especially in a household)
# twigging: branch out in a twiglike manner
# golconda: a source of great wealth (especially a mine)
# epitome: a standard or typical example
# almanac: an annual publication including weather forecasts and other miscellaneous information arranged according to the calendar of a given year
# taurus: Venezuelan master terrorist raised by a Marxist-Leninist father; trained and worked with many terrorist groups (born in 1949)
# navigator: the ship's officer in charge of navigation
# lecherous: given to excessive indulgence in sexual activity
# begets: make children
# cancer: any malignant growth or tumor caused by abnormal and uncontrolled cell division; it may spread to other parts of the body through the lymphatic system or the blood stream
# leo: (astrology) a person who is born while the sun is in Leo
# dabs: a light touch or stroke
# virgo: (astrology) a person who is born while the sun is in Virgo
# scorpio: (astrology) a person who is born while the sun is in Scorpio
# sagittarius: (astrology) a person who is born while the sun is in Sagittarius
# capricornus: a faint zodiacal constellation in the southern hemisphere; between Sagittarius and Aquarius
# aquarius: (astrology) a person who is born while the sun is in Aquarius
# drowns: cover completely or make imperceptible
# pisces: the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# luffs: (nautical) the forward edge of a fore-and-aft sail that is next to the mast
# copenhagen: the capital and largest city of Denmark; located on the island of Zealand
# interpreters: someone who mediates between speakers of different languages
# murray: British classical scholar (born in Australia) who advocated the League of Nations and the United Nations (1866-1957)
# darkey: (ethnic slur) offensive term for Black people
# hoard: a secret store of valuables or money
# blackberrying: pick or gather blackberries
# hussar: a member of a European light cavalry unit; renowned for elegant dress
# surcoat: a loose outer coat usually of rich material
# mallet: a sports implement with a long handle and a head like a hammer; used in sports (polo or croquet) to hit a ball
# abjectly: in a hopeless resigned manner
# changeful: such that alteration is possible; having a marked tendency to change
# tastefully: with taste; in a tasteful manner
# cruised: drive around aimlessly but ostentatiously and at leisure
# milling: corrugated edge of a coin
# befogged: make less visible or unclear
# looming: come into view indistinctly, often threateningly
# flailings: give a thrashing to; beat hard
# marlingspike: a pointed iron hand tool that is used to separate strands of a rope or cable (as in splicing)
# boomer: a member of the baby boom generation in the 1950s
# chimed: emit a sound
# toddies: a mixed drink made of liquor and water with sugar and spices and served hot
# bandages: a piece of soft material that covers and protects an injured part of the body
# spins: a swift whirling motion (usually of a missile)
# hydrophobia: a symptom of rabies in humans consisting of an aversion to swallowing liquids
# bait: anything that serves as an enticement
# mathematically: with respect to mathematics
# digestive: any substance that promotes digestion
# inscrutably: in an inscrutable manner
# digest: a periodical that summarizes the news
# feints: any distracting or deceptive maneuver (as a mock attack)
# ceylon: an island in the Indian Ocean off the southeastern coast of India
# tacks: the heading or position of a vessel relative to the trim of its sails
# pawn: an article deposited as security
# lancet: an acutely pointed Gothic arch, like a lance
# tudors: an English dynasty descended from Henry Tudor; Tudor monarchs ruled from Henry VII to Elizabeth I (from 1485 to 1603)
# bourbons: a reactionary politician in the United States (usually from the South)
# amelia: congenital absence of an arm or leg
# rattler: pit viper with horny segments at the end of the tail that rattle when shaken
# experimental: relating to or based on experiment
# flip: an acrobatic feat in which the feet roll over the head (either forward or backward) and return
# trumps: a playing card in the suit that has been declared trumps
# flipped: lightly throw to see which side comes up
# squally: characterized by short periods of noisy commotion
# reefed: lower and bring partially inboard
# tars: any of various dark heavy viscid substances obtained as a residue
# diluted: lessen the strength or flavor of a solution or mixture
# pickled: preserve in a pickling liquid
# symmetrically: in a symmetrical manner
# scorbutic: of or relating to or having or resembling scurvy
# hollanders: a native or inhabitant of Holland
# zealanders: a native or inhabitant of Zealand
# scrimps: subsist on a meager allowance
# musty: covered with or smelling of mold
# larders: a supply of food especially for a household
# lbs: 16 ounces avoirdupois
# geneva: a city in southwestern Switzerland at the western end of Lake Geneva; it is the headquarters of various international organizations
# statistical: of or relating to statistics
# flooded: fill quickly beyond capacity; as with a liquid
# transcendental: existing outside of or not in accordance with nature; -Aldous Huxley
# compiled: get or gather together
# fuddled: make stupid with alcohol
# boozy: given to or marked by the consumption of alcohol
# empties: a container that has been emptied
# descriptively: by giving a description
# structural: relating to or caused by structure, especially political or economic structure
# unbutton: undo the buttons of
# ultimatum: a final peremptory demand
# pinnings: a mutual promise of a couple not to date anyone else; on college campuses it was once signaled by the giving of a fraternity pin
# butteries: a small storeroom for storing foods or wines
# sheaths: a protective covering (as for a knife or sword)
# algiers: an ancient port on the Mediterranean; the capital and largest city of Algeria
# vertu: love of or taste for fine objects of art
# droopings: droop, sink, or settle from or as if from pressure or loss of tautness
# enfoldings: the action of enfolding something
# devotees: an ardent follower and admirer
# damocles: the Greek courtier to Dionysius the Elder who (according to legend) was condemned to sit under a naked sword that was suspended by a hair in order to demonstrate to him that being a king was not the happy state Damocles had said it was (4th century BC)
# tendrils: slender stem-like structure by which some twining plants attach themselves to an object for support
# ferns: any of numerous flowerless and seedless vascular plants having true roots from a rhizome and fronds that uncurl upward; reproduce by spores
# lacings: a small amount of liquor added to a food or beverage
# weaves: pattern of weaving or structure of a fabric
# deafened: be unbearably loud
# spindles: (biology) tiny fibers that are seen in cell division; the fibers radiate from two poles and meet at the equator in the middle
# villainies: the quality of evil by virtue of villainous behavior
# thinkings: the process of using your mind to consider something carefully
# intermixed: combine into one
# hummed: sing with closed lips
# trellised: train on a trellis, as of a vine
# wived: take (someone) as a wife
# eddied: flow in a circular current, of liquids
# arbours: a framework that supports climbing plants
# sconces: a shelter or screen providing protection from enemy fire or from the weather
# burton: English explorer who with John Speke was the first European to explore Lake Tanganyika (1821-1890)
# skeletons: something reduced to its minimal form
# verbatim: in precisely the same words used by a writer or speaker
# statistics: a branch of applied mathematics concerned with the collection and interpretation of quantitative data and the use of probability theory to estimate population parameters
# attenuated: weaken the consistency of (a chemical substance)
# eddyings: flow in a circular current, of liquids
# pompey: Roman general and statesman who quarrelled with Caesar and fled to Egypt where he was murdered (106-48 BC)
# urchins: poor and often mischievous city child
# amplify: increase in size, volume or significance
# involutions: reduction in size of an organ or part (as in the return of the uterus to normal size after childbirth)
# intestines: the part of the alimentary canal between the stomach and the anus
# hawsers: large heavy rope for nautical use
# exhaustive: performed comprehensively and completely
# seminal: pertaining to or containing or consisting of semen
# archaeological: related to or dealing with or devoted to archaeology
# fossiliferous: bearing or containing fossils
# grandiloquent: lofty in style
# weightiest: having relatively great weight; heavy
# dissertations: a treatise advancing a new point of view resulting from research; usually a requirement for an advanced academic degree
# lexicographer: a compiler or writer of a dictionary; a student of the lexical component of language
# compile: get or gather together
# chirography: beautiful handwriting
# placard: a sign posted in a public place as an advertisement
# condor: the largest flying birds in the western hemisphere
# penning: the act of creating written works
# mastodons: extinct elephant-like mammal that flourished worldwide from Miocene through Pleistocene times; differ from mammoths in the form of the molar teeth
# panoramas: the visual percept of a region
# excluding: prevent from being included or considered or accepted
# geologist: a specialist in geology
# tertiary: from 63 million to 2 million years ago
# formations: an arrangement of people or things acting as a unit
# intercepted: seize on its way
# disinterred: dig up for reburial or for medical investigation; of dead bodies
# antwerp: a busy port and financial center in northern Belgium on the Scheldt river; it has long been a center for the diamond industry and the first stock exchange was opened there in 1460
# anatomist: an expert in anatomy
# mutations: (biology) an organism that has characteristics resulting from chromosomal alteration
# characterized: describe or portray the character or the qualities or peculiarities of
# resemblances: similarity in appearance or external or superficial details
# affinities: (immunology) the attraction between an antigen and an antibody
# seniors: an undergraduate student during the year preceding graduation
# bastions: a group that defends a principle
# stereotype: a conventional or formulaic conception or image
# limestone: a sedimentary rock consisting mainly of calcium that was deposited by the remains of marine animals
# marl: a loose and crumbling earthy deposit consisting mainly of calcite or dolomite; used as a fertilizer for soils deficient in lime
# griffins: winged monster with the head of an eagle and the body of a lion
# cradled: hold gently and carefully
# osseous: composed of or containing bone
# diluvian: of or connected with a deluge
# mahomet: the Arab prophet who, according to Islam, was the last messenger of Allah (570-632)
# degenerated: grow worse
# exhumed: dig up for reburial or for medical investigation; of dead bodies
# tape: a long thin piece of cloth or paper as used for binding or fastening
# cooke: United States journalist (born in England in 1908)
# omniscient: infinitely wise
# manes: a Persian prophet who founded Manichaeism (216-276)
# canadian: a native or inhabitant of Canada
# statistically: with respect to statistics
# remunerative: for which money is paid
# swiss: the natives or inhabitants of Switzerland
# savannas: a flat grassland in tropical or subtropical regions
# citadels: a stronghold into which people could go for shelter during a battle
# floes: a flat mass of ice (smaller than an ice field) floating at sea
# goa: a state of southwestern India; a former Portuguese colony
# hannibal: general who commanded the Carthaginian army in the second Punic War; crossed the Alps and defeated the Romans but was recalled to defend Carthage and was defeated (247-182 BC)
# outlast: live longer than
# americas: North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776
# longevity: duration of service
# perishable: food that will decay rapidly if not refrigerated
# kremlin: citadel of Moscow, housing the offices of the Russian government
# netherlands: a constitutional monarchy in western Europe on the North Sea; half the country lies below sea level
# frothed: become bubbly or frothy or foaming
# precipitating: bring about abruptly
# thwart: a crosspiece spreading the gunnels of a boat; used as a seat in a rowboat
# splintering: the act of chipping something
# groin: the crease at the junction of the inner part of the thigh with the trunk together with the adjacent region and often including the external genitals
# marsh: low-lying wet land with grassy vegetation; usually is a transition zone between land and water
# perpetuates: cause to continue or prevail
# songster: a composer of words or music for popular songs
# canonic: appearing in a biblical canon
# childlessness: the condition of being without offspring
# pettiness: narrowness of mind or ideas or views
# archangelic: of or relating to or resembling archangels
# tracings: the act of drawing a plan or diagram or outline
# primogenitures: right of inheritance belongs exclusively to the eldest son
# signers: someone who can use sign language to communicate
# exclusiveness: tendency to associate with only a select group
# banned: forbid the public distribution of ( a movie or a newspaper)
# underived: not derived; primary or simple
# wails: a cry of sorrow and grief
# muffle: a kiln with an inner chamber for firing things at a low temperature
# transpire: pass through the tissue or substance or its pores or interstices, as of gas
# synod: a council convened to discuss ecclesiastical business
# potentates: a ruler who is unconstrained by law
# procedures: a particular course of action intended to achieve a result
# functionary: a worker who holds or is invested with an office
# fittings: making or becoming suitable; adjusting to circumstances
# blacksmith: a smith who forges and shapes iron with a hammer and anvil
# forging: shaping metal by heating and hammering
# duplicates: something additional of the same kind
# callings: the particular occupation for which you are trained
# handicrafts: a work produced by hand labor
# reforming: make changes for improvement in order to remove abuse and injustices
# bladed: bearing or characterized by a blade or sword; often used in combination
# unhesitatingly: without hesitation
# conflicting: be in conflict
# aptitudes: inherent ability
# enacted: order by virtue of superior authority; decree
# belaying: turn a rope round an object or person in order to secure it or him
# sprains: a painful injury to a joint caused by a sudden wrenching of its ligaments
# concocts: make a concoction (of) by mixing
# lotion: any of various cosmetic preparations that are applied to the skin
# vermillion: of a vivid red to reddish-orange color
# unmanageably: so as to be unmanageable
# winces: the facial expression of sudden pain
# capstans: a windlass rotated in a horizontal plane around a vertical axis; used on ships for weighing anchor or raising heavy sails
# expertness: skillfulness by virtue of possessing special knowledge
# impersonal: not relating to or responsive to individual persons
# ignores: refuse to acknowledge
# ramifying: have or develop complicating consequences
# heartlessness: an absence of concern for the welfare of others
# wheezing: breathe with difficulty
# wittiness: a message whose ingenuity or verbal skill or incongruity has the power to evoke laughter
# clingings: come or be in close contact with; stick or hold together and resist separation
# intermixture: any foodstuff made by combining different ingredients
# uneven: not even or uniform as e.g. in shape or texture
# manipulator: an agent that operates some apparatus or machine
# oozed: pass gradually or leak through or as if through small openings
# parvo: any of a group of viruses containing DNA in an icosahedral protein shell and causing disease in dogs and cattle; not known to be associated with any human disease
# sheffield: a steel manufacturing city in northern England famous for its cutlery industry
# drivers: the operator of a motor vehicle
# screws: someone who guards prisoners
# tweezers: a hand tool for holding consisting of a compound lever for grasping
# awls: a pointed tool for marking surfaces or for punching small holes
# filers: a party who files a notice with a law court
# quicksilver: a heavy silvery toxic univalent and bivalent metallic element; the only metal that is liquid at ordinary temperatures
# abided: dwell
# soliloquizing: talk to oneself
# soliloquizes: talk to oneself
# amputate: remove surgically
# smut: a black colloidal substance consisting wholly or principally of amorphous carbon and used to make pigments and ink
# shinbone: the inner and thicker of the two bones of the human leg between the knee and ankle
# doctored: alter and make impure, as with the intention to deceive
# lotions: any of various cosmetic preparations that are applied to the skin
# africans: a native or inhabitant of Africa
# pedlar: someone who travels about selling his wares (as on the streets or at carnivals)
# modelled: plan or create according to a model or models
# catcher: (baseball) the person who plays the position of catcher
# thrusted: push forcefully
# poser: a person who habitually pretends to be something he is not
# eavesdroppers: a secret listener to private conversations
# bungle: an embarrassing mistake
# inter: place in a grave or tomb
# indebtedness: an obligation to pay money to another party
# ledgers: a record in which commercial accounts are recorded
# praetorians: a member of the Praetorian Guard
# auction: a variety of bridge in which tricks made in excess of the contract are scored toward game; now generally superseded by contract bridge
# crucible: a vessel made of material that does not melt easily; used for high temperature chemical reactions
# compendious: briefly giving the gist of something
# dinning: make a resonant sound, like artillery
# chucks: informal terms for a meal
# spavined: (of horses) afflicted with a swelling of the hock-joint
# semiweekly: a periodical that is published twice each week (or 104 issues per year)
# drench: drench or submerge or be drenched or submerged
# damply: in a damp manner
# leakage: the discharge of a fluid from some container
# formosa: an island in southeastern Asia 100 miles off the coast of mainland China in the South China Sea
# burtons: English explorer who with John Speke was the first European to explore Lake Tanganyika (1821-1890)
# nearing: move towards
# miserly: (used of persons or behavior) characterized by or indicative of lack of generosity
# musket: a muzzle-loading shoulder gun with a long barrel; formerly used by infantrymen
# waxes: any of various substances of either mineral origin or plant or animal origin; they are solid at normal temperatures and insoluble in water
# plaits: a hairdo formed by braiding or twisting the hair
# furl: form into a cylinder by rolling
# disaffection: the feeling of being alienated from other people
# lowermost: farthest down
# placards: a sign posted in a public place as an advertisement
# shooks: a disassembled barrel; the parts packed for storage or shipment
# demijohn: large bottle with a short narrow neck; often has small handles at neck and is enclosed in wickerwork
# sinecures: a benefice to which no spiritual or pastoral duties are attached
# clumsiest: lacking grace in movement or posture
# stowage: the charge for stowing goods
# holders: a holding device
# disembowelled: remove the entrails of
# dampness: a slight wetness
# zoroaster: Persian prophet who founded Zoroastrianism (circa 628-551 BC)
# impresses: the act of coercing someone into government service
# embalming: preserve a dead body
# horizons: the line at which the sky and Earth appear to meet
# chalking: write, draw, or trace with chalk
# extremities: an external body part that projects from the body
# sobbings: convulsive gasp made while weeping
# rover: someone who leads a wandering unsettled life
# antilles: a group of islands in the West Indies
# probed: question or examine thoroughly and closely
# vouchers: someone who vouches for another or for the correctness of a statement
# convalescing: get over an illness or shock
# unfold: develop or come to a promising stage
# moulder: break down
# tantalization: the act of harassing someone playfully or maliciously (especially by ridicule); provoking someone with persistent annoyances
# eastwards: the cardinal compass point that is at 90 degrees
# stirrings: agitating a liquid with an implement
# ebb: a gradual decline (in size or strength or power or number)
# somnambulisms: walking by a person who is asleep
# slumberers: a rester who is sleeping
# midmost: being in the exact middle
# recentest: new
# japans: a string of more than 3,000 islands to the east of Asia extending 1,300 miles between the Sea of Japan and the western Pacific Ocean
# sugary: containing sugar
# delta: a low triangular area of alluvial deposits where a river divides before entering a larger body of water
# perth: the state capital of Western Australia
# blistered: get blistered
# contributory: tending to bring about; being partly responsible for
# jealously: with jealousy
# chronically: in a habitual and longstanding manner
# yawing: be wide open
# technicals: a pickup truck with a gun mounted on it
# artisan: a skilled worker who practices some trade or handicraft
# blithe: lacking or showing a lack of due concern
# conjuror: someone who performs magic tricks to amuse an audience
# economic: of or relating to an economy, the system of production and management of material wealth
# basement: the lowermost portion of a structure partly or wholly below ground level; often used for storage
# cinders: a fragment of incombustible matter left after a wood or coal or charcoal fire
# compunctions: a feeling of deep regret (usually for some misdeed)
# receptive: open to arguments, ideas, or change
# oblivious: (followed by `to' or `of') lacking conscious awareness of
# gravestone: a stone that is used to mark a grave
# welding: fastening two pieces of metal together by softening with heat and applying pressure
# seams: joint consisting of a line formed by joining two pieces
# gaffs: a sharp metal spike or spur that is fastened to the leg of a gamecock
# stubbs: English historian noted for his constitutional history of medieval England (1825-1901)
# stubbornest: tenaciously unwilling or marked by tenacious unwillingness to yield
# weld: European mignonette cultivated as a source of yellow dye; naturalized in North America
# glue: cement consisting of a sticky substance that is used as an adhesive
# lucifers: (Judeo-Christian and Islamic religions) chief spirit of evil and adversary of God; tempter of mankind; master of Hell
# fusee: a spirally grooved spindle in a clock that counteracts the diminishing power of the uncoiling mainspring
# wincing: draw back, as with fear or pain
# branding: the act of stigmatizing
# razors: edge tool used in shaving
# tempering: hardening something by heat treatment
# ego: an inflated feeling of pride in your superiority to others
# te: a brittle silver-white metalloid element that is related to selenium and sulfur; it is used in alloys and as a semiconductor; occurs mainly as tellurides in ores of copper and nickel and silver and gold
# baptismal: of or relating to baptism
# unwound: reverse the winding or twisting of
# strandings: leave stranded or isolated with little hope of rescue
# mummeries: meaningless ceremonies and flattery
# gilder: someone whose occupation is to apply an overlay of gold or gilt
# purr: a low vibrating sound typical of a contented cat
# conceals: prevent from being seen or discovered
# fang: a Bantu language spoken in Cameroon
# mixes: a commercially prepared mixture of dry ingredients
# interpenetrate: penetrate mutually or be interlocked
# seamless: not having or joined by a seam or seams
# tarnishing: make dirty or spotty, as by exposure to air; also used metaphorically
# adolescence: the time period between the beginning of puberty and adulthood
# weariest: physically and mentally fatigued
# foundling: a child who has been abandoned and whose parents are unknown
# unwedded: of someone who has not been married
# paternity: the state of being a father
# tiered: having or arranged in tiers
# oust: remove from a position or office
# bunting: a loosely woven fabric used for flags, etc.
# bartered: exchange goods without involving money
# kindling: material for starting a fire
# centrepiece: the central or most important feature
# caulked: seal with caulking
# plugged: fill or close tightly with or as if with a plug
# eloped: run away secretly with one's beloved
# jubilations: a feeling of extreme joy
# spearings: pierce with a spear
# stilly: (poetic) still or calm
# plaintiveness: expressing sorrowfulness
# orisons: reverent petition to a deity
# wanings: a gradual decrease in magnitude or extent
# vassal: a person holding a fief; a person who owes allegiance and service to a feudal lord
# unspoken: expressed without speech; ; ; - Emily Dickinson; ; ; - Thomas Wolfe
# whirls: confused movement
# slaughtering: kill (animals) usually for food consumption
# hooped: bind or fasten with a hoop
# intercedings: act between parties with a view to reconciling differences
# imminglings: combine into one
# suckled: suck milk from the mother's breasts
# mothered: care for like a mother
# foster: United States songwriter whose songs embody the sentiment of the South before the American Civil War (1826-1864)
# flickering: move back and forth very rapidly
# squadrons: a cavalry unit consisting of two or more troops and headquarters and supporting arms
# hearses: a vehicle for carrying a coffin to a church or a cemetery; formerly drawn by horses but now usually a motor vehicle
# quadrant: a quarter of the circumference of a circle
# unblinkingly: showing no emotion
# splendors: a quality that outshines the usual
# astrological: relating to or concerned with astrology
# revery: an abstracted state of absorption
# plaything: an artifact designed to be played with
# brags: an instance of boastful talk
# impotence: the quality of lacking strength or power; being weak and feeble
# scorches: a surface burn
# fatalistic: of or relating to fatalism
# awestruck: having or showing a feeling of mixed reverence and respect and wonder and dread
# erectly: in a straight-backed manner
# pirouetting: do a pirouette, usually as part of a dance
# dumbest: slow to learn or understand; lacking intellectual acuity; ; ; - Thackeray
# crouches: the act of bending low with the limbs close to the body
# cloudless: free from clouds
# exploding: cause to burst with a violent release of energy
# poled: propel with a pole
# teetering: move unsteadily, with a rocking motion
# sporty: exhibiting or calling for sportsmanship or fair play
# gamy: suggestive of sexual impropriety
# splits: extending the legs at right angles to the trunk (one in front and the other in back)
# smacks: a blow from a flat object (as an open hand)
# lightens: make more cheerful
# mishaps: an unpredictable outcome that is unfortunate
# impeding: be a hindrance or obstacle to
# flambeaux: a flaming torch (such as are used in processions at night)
# teeter: a plaything consisting of a board balanced on a fulcrum; the board is ridden up and down by children at either end
# pallidness: unnatural lack of color in the skin (as from bruising or sickness or emotional distress)
# phosphorescence: a fluorescence that persists after the bombarding radiation has ceased
# tableau: a group of people attractively arranged (as if in a painting)
# chock: a block of wood used to prevent the sliding or rolling of a heavy object
# supernaturalness: the quality of being attributed to power that seems to violate or go beyond natural forces
# cohered: come or be in close contact with; stick or hold together and resist separation
# numbed: make numb or insensitive
# wasps: a white person of Anglo-Saxon ancestry who belongs to a Protestant denomination
# upcast: air passage consisting of a ventilation shaft through which air leaves a mine
# sacramental: of or relating to or involving a sacrament
# queenly: having the rank of or resembling or befitting a queen
# supernal: being or coming from on high
# closes: the temporal end; the concluding time
# blindfold: a cloth used to cover the eyes
# creativeness: the ability to create
# transfix: to render motionless, as with a fixed stare or by arousing terror or awe
# neighborhood: a surrounding or nearby region
# inboard: located within the hull or nearest the midline of a vessel or aircraft
# coasting: move effortlessly; by force of gravity
# colic: acute abdominal pain (especially in infants)
# lashings: a large number or amount
# afire: lighted up by or as by fire or flame
# drenching: the act of making something completely wet
# guarantees: a written assurance that some product or service will be provided or will meet certain specifications
# hydrants: a faucet for drawing water from a pipe or cask
# skewered: drive a skewer through
# togs: informal terms for clothing
# falsified: make false by mutilation or addition; as of a message or story
# apprise: inform (somebody) of something
# fitfully: in a fitful manner
# fitful: occurring in spells and often abruptly
# gropes: the act of groping; and instance of groping
# ahabs: according to the Old Testament he was a pagan king of Israel and husband of Jezebel (9th century BC)
# caged: confine in a cage
# stealthily: in a stealthy manner
# boomed: make a resonant sound, like artillery
# babylonian: an inhabitant of ancient Babylon
# loweringly: in a menacing or scowling way
# rearward: direction toward the rear
# loadstone: a permanent magnet consisting of magnetite that possess polarity and has the power to attract as well as to be attracted magnetically
# recovers: get or find back; recover the use of
# reaches: the limits within which something can be effective
# rumbled: make a low noise
# unimpressed: not moved to serious regard
# magnetism: attraction for iron; associated with electric currents as well as magnets; characterized by fields of force
# clumsily: in a clumsy manner
# blunted: make less intense
# magnetizing: make magnetic
# damped: deaden (a sound or noise), especially by wrapping
# warped: make false by mutilation or addition; as of a message or story
# tahitian: a native or inhabitant of Tahiti
# grizzly: powerful brownish-yellow bear of the uplands of western North America
# spool: a winder around which thread or tape or film or other flexible materials can be wound
# unwinding: reverse the winding or twisting of
# unmanned: cause to lose one's nerve
# sagged: droop, sink, or settle from or as if from pressure or loss of tautness
# loon: a worthless lazy fellow
# ding: a ringing sound
# dong: the basic unit of money in Vietnam
# daft: informal or slang terms for mentally irregular
# wailings: loud cries made while weeping
# dams: a barrier constructed to contain the flow of water or to keep out the sea
# bodings: a feeling of evil to come
# shrunken: wither, as with a loss of moisture
# foreshadowing: the act of providing vague advance indications; representing beforehand
# presaged: indicate by signs
# caulk: a waterproof filler and sealant that is used in building and repair to make watertight
# caulking: a waterproof filler and sealant that is used in building and repair to make watertight
# baulks: the area on a billiard table behind the balkline
# bandbox: a light cylindrical box for holding light articles of attire (especially hats)
# cobbling: the shoemaker's trade
# tinkers: a person who enjoys fixing and experimenting with machines and their parts
# brats: a very troublesome child
# tinkerings: do random, unplanned work or activities or spend time idly
# jobs: the principal activity in your life that you do to earn money
# cobbler: a person who makes or repairs shoes
# batten: stuffing made of rolls or sheets of cotton wool or synthetic fiber
# knotty: making great mental demands; hard to comprehend or solve or believe
# complies: act in accordance with someone's rules, commands, or wishes
# aisle: a long narrow passage (as in a cave or woods)
# titans: a person of exceptional importance and reputation
# chipping: the act of chipping something
# tat: tastelessness by virtue of being cheap and vulgar
# imponderable: a factor whose effects cannot be accurately assessed
# conduits: a passage (a pipe or tunnel) through which water or electric wires can pass
# bladders: a distensible membranous sac (usually containing liquid or gas)
# throttling: the act of suffocating (someone) by constricting the windpipe
# negatively: in a harmful manner
# icily: in a cold and icy manner
# charter: a document incorporating an institution and specifying its rights; includes the articles of incorporation and the certificate of incorporation
# adopting: choose and follow; as of theories, ideas, policies, strategies or plans
# iciness: coldness due to a cold environment
# hardihood: the trait of being willing to undertake things that involve risk or danger
# initiate: someone new to a field or activity
# nestling: young bird not yet fledged
# gardiner: British historian remembered for his ten-volume history of England (1829-1902)
# transfixed: to render motionless, as with a fixed stare or by arousing terror or awe
# tack: the heading or position of a vessel relative to the trim of its sails
# bigot: a prejudiced person who is intolerant of any opinions differing from his own
# fours: the cardinal number that is the sum of three and one
# epaulets: adornment consisting of an ornamental cloth pad worn on the shoulder
# monsieurs: used as a French courtesy title; equivalent to English `Mr'
# bulge: something that bulges out or is protuberant or projects from its surroundings
# contrastingly: in a contrasting manner
# concurred: be in accord; be in agreement
# sustains: lengthen or extend in duration or space
# domineered: rule or exercise power over (somebody) in a cruel and autocratic manner
# gnarled: twist into a state of deformity
# siding: a short stretch of railroad track used to store rolling stock or enable trains on the same line to pass
# slided: move obliquely or sideways, usually in an uncontrolled manner
# reeved: pass a rope through
# shunning: deliberately avoiding; keeping away from or preventing from happening
# fastenings: restraint that attaches to something or holds something in place
# swooping: move down on as if in an attack
# billed: demand payment
# tarquin: according to legend, the seventh and last Etruscan king of Rome who was expelled for his cruelty (reigned from 534 to 510 BC)
# misnamed: assign in incorrect name to
# shears: large scissors with strong blades
# unrigged: stripped of rigging
# bleaching: remove color from
# symphony: a long and complex sonata for symphony orchestra
# firmaments: the apparent surface of the imaginary sphere on which celestial bodies appear to be projected
# ...
# trumpeter: a musician who plays the trumpet or cornet
# vibrates: shake, quiver, or throb; move back and forth rapidly, usually in an uncontrolled manner
# composer: someone who composes music as a profession
# chaotically: in a wild and confused manner
# numb: make numb or insensitive
# sensuous: taking delight in beauty
# contestants: a person who participates in competitions
# incased: enclose in, or as if in, a case
# alembic: an obsolete kind of container used for distillation; two retorts connected by a tube
# cannoneers: a serviceman in the artillery
# feuds: a bitter quarrel between two parties
# hatreds: the emotion of intense dislike; a feeling of dislike so strong that it demands action
# bacchanals: someone who engages in drinking bouts
# dual: consisting of or involving two parts or components usually in pairs
# cylindric: having the form of a cylinder
# shuttling: travel back and forth between two points
# buffeting: repeated heavy blows
# gusts: a strong current of air
# debonair: having a sophisticated charm
# glib: marked by lack of intellectual depth
# slivery: resembling or consisting of or embedded with long slender fragments of (especially) wood having sharp points
# savannah: a port in eastern Georgia near the mouth of the Savannah river
# santee: a member of the eastern branch of the Sioux
# coosa: river that rises in northwestern Georgia and flows southwest through eastern Alabama to join the Tallapoosa River near Montgomery and form the Alabama River
# sabine: a river in eastern Texas that flows south into the Gulf of Mexico
# okeechobee: a lake in southeast Florida to the north of the Everglades
# hummock: a small natural hill
# parrots: usually brightly colored zygodactyl tropical birds with short hooked beaks and the ability to mimic sounds
# papaw: small tree native to the eastern United States having oblong leaves and fleshy fruit
# titi: tree of low-lying coastal areas of southeastern United States having glossy leaves and racemes of fragrant white flowers
# coaster: a resident of a coastal area
# palmetto: any of several low-growing palms with fan-shaped leaves
# pamlico: a member of the Algonquian people formerly of the Pamlico river valley in North Carolina
# cactus: any succulent plant of the family Cactaceae native chiefly to arid regions of the New World and usually having spines
# freebooter: someone who takes spoils or plunder (as in war)
# infested: invade in great numbers
# reptiles: any cold-blooded vertebrate of the class Reptilia including tortoises, turtles, snakes, lizards, alligators, crocodiles, and extinct forms
# raccoon: the fur of the North American racoon
# opossum: small furry Australian arboreal marsupials having long usually prehensile tails
# nested: inhabit a nest, usually after building
# villas: Mexican revolutionary leader (1877-1923)
# jobbers: someone who buys large quantities of goods and resells to merchants rather than to the ultimate customers
# cunningest: attractive especially by means of smallness or prettiness or quaintness
# costless: costing nothing
# sculptor: an artist who creates sculptures
# vocalist: a person who sings
# assemblage: a group of persons together in one place
# radiations: energy that is radiated or transmitted in the form of rays or waves or particles
# staked: put at risk
# martyrdoms: death that is imposed because of the person's adherence of a religious faith or cause
# unreachable: inaccessibly located or situated
# excelsior: thin curly wood shavings used for packing or stuffing
# poverties: the state of having little or no money and few or no material possessions
# wincings: draw back, as with fear or pain
# smarts: a kind of pain such as that caused by a wound or a burn or a sore
# articulations: the aspect of pronunciation that involves bringing articulatory organs together so as to shape the sounds of speech
# meannesses: the quality of being deliberately mean
# ennuis: the feeling of being bored by something tedious
# fiat: a legally binding command or decision entered on the court record (as if issued by a court or judge)
# venerableness: the quality of deserving veneration
# dicta: an authoritative declaration
# democracies: the political orientation of those who favor government by the people or by their elected representatives
# envelopment: the act of enclosing something inside something else
# amative: inclined toward or displaying love
# perceptive: of or relating to perception
# finders: someone who comes upon something after searching
# conveyers: a person who conveys (carries or transmits)
# crumble: fall apart
# ejaculating: utter impulsively
# pellucid: transmitting light; able to be seen through with clarity
# canyons: a ravine formed by a river in an area with little rainfall
# sioux: a member of a group of North American Indian peoples who spoke a Siouan language and who ranged from Lake Michigan to the Rocky Mountains
# bulletin: a brief report (especially an official statement issued for immediate publication or broadcast)
# ambuscade: the act of concealing yourself and lying in wait to attack by surprise
# custer: United States general who was killed along with all his command by the Sioux at the Battle of Little Bighorn (1839-1876)
# interwoven: interlace by or as if by weaving
# feted: have a celebration
# canyon: a ravine formed by a river in an area with little rainfall
# arrays: an orderly arrangement
# lyrist: a person who writes the words for songs
# denser: permitting little if any light to pass through because of denseness of matter
# foremen: a person who exercises control over workers
# xxxiii: being three more than thirty
# glooming: depressingly dark
# dramas: a dramatic work intended for performance by actors on a stage
# solidarity: a union of interests or purposes or sympathies among members of a group
# stupendous: so great in size or force or extent as to elicit awe
# denouements: the outcome of a complex sequence of events
# countermarching: march back along the same way
# boundaries: the line or plane indicating the limit or extent of something
# aristocracies: a privileged class holding hereditary titles
# colonizes: settle as a colony; of countries in the developing world
# wholesale: the selling of goods to merchants; usually in large quantities for resale to consumers
# interlinks: be interwoven or interconnected
# confronts: oppose, as in hostility or a competition
# reveille: (military) signal to wake up
# marts: an area in a town where a public mercantile establishment is set up
# foetor: a distinctive odor that is offensively unpleasant
# fructify: become productive or fruitful
# parturitions: the process of giving birth
# despairingly: with desperation
# willful: done by design
# transitions: the act of passing from one state or place to the next
# sitka: a town in southeastern Alaska that was the capital of Russian America and served as the capital of Alaska from 1867 until 1906
# completer: having every necessary or normal part or component or step
# inalienable: incapable of being repudiated or transferred to another
# litheness: the gracefulness of a person or animal that is flexible and supple
# tiniest: very small
# exquisiteness: extreme beauty of a delicate sort
# intersperse: place at intervals in or among
# finales: the closing section of a musical composition
# tombstone: a stone that is used to mark a grave
# acquirer: a person who acquires something (usually permanently)
# devises: a will disposing of real property
# bequeaths: leave or give by will after one's death
# battlefields: a region where a battle is being (or has been) fought
# redden: turn red, as if in embarrassment or shame
# lessens: decrease in size, extent, or range
# countersign: a secret word or phrase known only to a restricted group
# dotting: scatter or intersperse like dots or studs
# underlies: be or form the base for
# encompassing: include in scope; include as part of something broader; have as one's sphere or territory
# consummations: the completion of marriage by sexual intercourse
# dallier: someone who wastes time
# translations: a written communication in a second language having the same meaning as the written communication in a first language
# xxxiv: being four more than thirty
# salty: engagingly stimulating or provocative
# inbound: directed or moving inward or toward a center
# inertia: a disposition to remain inactive or inert
# font: a specific size and style of type within a type family
# nonpareil: model of excellence or perfection of a kind; one having no equal
# glooms: a state of partial or total darkness
# constipation: irregular and infrequent or difficult evacuation of the bowels; can be a symptom of intestinal obstruction or diverticulitis
# seventieth: position 70 in a countable series of things
# screeching: a high-pitched noise resembling a human cry
# splints: a thin sliver of wood
# winners: the contestant who wins the contest
# converged: be adjacent or come together
# feb: the month following January and preceding March
# carpeted: form a carpet-like cover (over)
# halcyon: (Greek mythology) a woman who was turned into a kingfisher
# balmier: informal or slang terms for mentally irregular
# contends: maintain or assert
# looms: a textile machine for weaving yarn into a textile
# ajax: a mythical Greek hero; a warrior who fought against Troy in the Iliad
# lear: British artist and writer of nonsense verse (1812-1888)
# othello: the hero of William Shakespeare's tragedy who would not trust his wife
# metre: the basic unit of length adopted under the Systeme International d'Unites (approximately 1.094 yards)
# capella: the brightest star in Auriga
# vivifies: give new life or energy to
# landward: toward land
# incoming: the act of entering
# glamour: alluring beauty or charm (often with sex-appeal)
# offsetting: compensate for or counterbalance
# dilates: become wider
# mainsails: the lowermost sail on the mainmast
# ephemeral: anything short-lived, as an insect that lives only for a day in its winged form
# powerfulest: having great power or force or potency or effect
# rifts: a gap between cloud masses
# geyser: a spring that discharges hot water and steam
# ballot: a document listing the alternatives that is used in voting
# foams: a mass of small bubbles formed in or on a liquid
# ferments: a state of agitation or turbulent change or development
# imaging: the ability to form mental images of things or events
# racers: someone who drives racing cars at high speeds
# dimples: a chad that has been punched or dimpled but all four corners are still attached
# hurricanes: a severe tropical cyclone usually with heavy rains and winds moving a 73-136 knots (12 on the Beaufort scale)
# rasping: uttering in an irritated tone
# undertones: a quiet or hushed tone of voice
# dismays: the feeling of despair in the face of obstacles
# cumulus: a globular cloud
# flagstones: stratified stone that splits into pieces suitable as paving stones
# colored: a United States term for Blacks that is now considered offensive
# lilt: a jaunty rhythm in music
# diagnose: determine or distinguish the nature of a problem or an illness through a diagnostic analysis
# outbound: that is going out or leaving
# timbre: (music) the distinctive property of a complex sound (a voice or noise or musical sound)
# transmuting: change in outward structure or looks
# correlation: a reciprocal relation between two or more things
# continuities: uninterrupted connection or union
# noons: the middle of the day
# tableaux: a group of people attractively arranged (as if in a painting)
# undiscouraged: not deterred; - Osbert Sitwell
# battling: battle or contend against in or as if in a battle
# geologies: a science that deals with the history of the earth as recorded in rocks
# bettering: surpass in excellence
# insoluble: (of a substance) incapable of being dissolved
# drouths: a prolonged shortage
# ligatures: (music) a group of notes connected by a slur
# unbind: untie or unfasten
# chills: coldness due to a cold environment
# cognizance: having knowledge of
# dandelions: any of several herbs of the genus Taraxacum having long tap roots and deeply notched leaves and bright yellow flowers followed by fluffy seed balls
# arbutus: any of several evergreen shrubs of the genus Arbutus of temperate Europe and America
# bluebird: fruit-eating mostly brilliant blue songbird of the East Indies
# spiritualistic: of or relating to or connected with spiritualism
# reconnoitering: exploring in order to gain information
# sparse: not dense
# overstay: stay too long
# hardiest: having rugged physical strength; inured to fatigue or hardships
# sheltering: provide shelter for
# lagoon: a body of water cut off from a larger body by a reef of sand or coral
# rusting: the formation of reddish-brown ferric oxides on iron by low-temperature oxidation in the presence of water
# pulsing: (electronics) a sharp transient wave in the normal electrical state (or a series of such transients)
# severance: a personal or social separation (as between opposing factions)
# farewells: an acknowledgment or expression of goodwill at parting
# garrulous: full of trivial conversation
# confirmations: additional proof that something that was believed (some fact or hypothesis or theory) is correct
# strayings: move about aimlessly or without any destination, often in search of food or employment
# gladsome: experiencing or expressing gladness or joy
# horde: a vast multitude
# concepts: an abstract or general idea inferred or derived from specific instances
# ashy: of a light grey
# vitalities: an energetic style
# blitheness: a feeling of spontaneous good spirits
# jubilate: celebrate a jubilee
# studding: scatter or intersperse like dots or studs
# affectations: a deliberate pretense or exaggerated display
# lisps: a speech defect that involves pronouncing `s' like voiceless `th' and `z' like voiced `th'
# scorns: lack of respect accompanied by a feeling of intense dislike
# eleemosynary: generous in assistance to the poor
# encrustations: the formation of a crust
# oversea: being or passing over or across the sea
# interpolation: a message (spoken or written) that is introduced or inserted
# vitalizing: give life to
# idyls: a musical composition that evokes rural life
# odyssey: a long wandering and eventful journey
# hesiod: Greek poet whose existing works describe rural life and the genealogies of the gods and the beginning of the world (eighth century BC)
# sophocles: one of the great tragedians of ancient Greece (496-406 BC)
# cid: the United States Army's principal law enforcement agency responsible for the conduct of criminal investigations for all levels of the Army anywhere in the world
# nibelungen: (German mythology) a companion or follower of Siegfried
# schiller: German romantic writer (1759-1805)
# reveals: make visible
# impedimentas: any structure that makes progress difficult
# unreconciled: not made consistent or compatible
# blender: an electrically powered mixer with whirling blades that mix or chop or liquefy foods
# reconciles: make (one thing) compatible with (another)
# blends: an occurrence of thorough mixing
# whelming: overcome, as with emotions or perceptual stimuli
# cataclysm: a sudden violent change in the earth's surface
# permeate: spread or diffuse through
# sufi: a Muslim who represents the mystical dimension of Islam; a Muslim who seeks direct experience of Allah; mainly in Iran
# immanent: of a mental act performed entirely within the mind
# gluttony: habitual eating to excess
# mainest: most important element
# twentieths: position 20 in a countable series of things
# newts: small usually bright-colored semiaquatic salamanders of North America and Europe and northern Asia
# shopfronts: the front side of a store facing the street; usually contains display windows
# confab: an informal conversation
# glum: moody and melancholic
# demarcate: separate clearly, as if by boundaries
# cumulative: increasing by successive addition
# abandoning: forsake, leave behind
# poesy: literature in metrical form
# endowing: give qualities or abilities to
# delving: turn up, loosen, or remove earth
# germinal: seventh month of the Revolutionary calendar (March and April); the month of buds
# blither: to talk foolishly
# ushering: take (someone) to their seats, as in theaters or auditoriums

# %% [markdown]
# #5)N-gram Tokenization

# %%
import nltk
nltk.download('punkt')

from nltk.corpus import webtext
from nltk.probability import FreqDist
from nltk.util import ngrams
import pandas as pd
import matplotlib.pyplot as plt
nltk.download('webtext')
dataset = webtext.raw()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Unzipping corpora/webtext.zip.

# %%
unigrams = nltk.word_tokenize(dataset)
bigrams = list(ngrams(unigrams, 2))
trigrams = list(ngrams(unigrams, 3))

# %%
unigram_freq = FreqDist(unigrams)
bigram_freq = FreqDist(bigrams)
trigram_freq = FreqDist(trigrams)

# %%
# Unigram frequency distribution
plt.figure(figsize=(12, 6))
unigram_freq.plot(50, cumulative=False)
plt.show()

# Bigram frequency distribution
plt.figure(figsize=(12, 6))
bigram_freq.plot(50, cumulative=False)
plt.show()

# Trigram frequency distribution
plt.figure(figsize=(12, 6))
trigram_freq.plot(50, cumulative=False)
plt.show()
